# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from textblob import TextBlob
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# %%
reviews = pd.read_csv('belcanto_reviews_with_dates_complete.csv')

# %%
reviews.head()
# Out:
#      stars                                             review          date
# 0  5 stars  The service is exceptionally good. Restaurant ...   a month ago
# 1  5 stars  100% recommend the tasting menu! 250€ per pers...   3 weeks ago
# 2  4 stars  March 9th 2024, dinner at Belcanto (in Lisbon)...  4 months ago
# 3  5 stars  Very nice restaurant in Lisboa, nice touch wit...  2 months ago
# 4   1 star  I visited Belcanto with high expectations give...  3 months ago

# %%
reviews["score"] = reviews["stars"].str.extract(r'(\d+)').astype(int)

# %%
reviews.head()
# Out:
#      stars                                             review          date  \
# 0  5 stars  The service is exceptionally good. Restaurant ...   a month ago
# 1  5 stars  100% recommend the tasting menu! 250€ per pers...   3 weeks ago
# 2  4 stars  March 9th 2024, dinner at Belcanto (in Lisbon)...  4 months ago
# 3  5 stars  Very nice restaurant in Lisboa, nice touch wit...  2 months ago
# 4   1 star  I visited Belcanto with high expectations give...  3 months ago
#
#    score
# 0      5
# 1      5
# 2      4
# 3      5
# 4      1

# %%
# Enhanced function to calculate the review date
def calculate_review_date(row_date):
    now = datetime.now()
    try:
        if "month" in row_date:
            if "a month ago" in row_date:  # Special case for "a month ago"
                return now - timedelta(days=30)
            months = int(row_date.split()[0])
            return now - timedelta(days=30 * months)
        elif "year" in row_date:
            if "a year ago" in row_date:  # Special case for "a year ago"
                return now - timedelta(days=365)
            years = int(row_date.split()[0])
            return now - timedelta(days=365 * years)
        elif "week" in row_date:
            if "a week ago" in row_date:  # Special case for "a week ago"
                return now - timedelta(weeks=1)
            weeks = int(row_date.split()[0])
            return now - timedelta(weeks=weeks)
        elif "day" in row_date:
            if "a day ago" in row_date:  # Special case for "a day ago"
                return now - timedelta(days=1)
            days = int(row_date.split()[0])
            return now - timedelta(days=days)
        else:
            return None  # Fallback for unexpected formats
    except (ValueError, IndexError):
        return None

# Apply the updated function to the 'date' column
reviews["date_of_review"] = reviews["date"].apply(calculate_review_date)

# Display the updated DataFrame
reviews.head()
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354 entries, 0 to 353
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   stars           354 non-null    object
#  1   review          354 non-null    object
#  2   date            354 non-null    object
#  3   score           354 non-null    int64
#  4   date_of_review  354 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 14.0+ KB

# %%
df = reviews.copy()

# Preprocessing: Removing special characters and converting to lowercase
df["cleaned_review"] = df["review"].str.replace(r"[^a-zA-Z\s]", "", regex=True).str.lower()

# %%
# Word count
df["word_count"] = df["cleaned_review"].apply(lambda x: len(x.split()))

# Sentence count
df["sentence_count"] = df["review"].apply(lambda x: len(x.split(".")))

# Display average stats
print(f"Average word count: {df['word_count'].mean()}")
print(f"Average sentence count: {df['sentence_count'].mean()}")
# Out:
# Average word count: 31.070621468926554
# Average sentence count: 3.327683615819209

# %%
### 1. Sentiment Analysis
def calculate_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

# Apply the sentiment analysis to the 'review' column
reviews['sentiment_score'] = reviews['review'].apply(calculate_sentiment)

# Basic sentiment categorization
reviews['sentiment_category'] = pd.cut(
    reviews['sentiment_score'],
    bins=[-1, -0.05, 0.05, 1],
    labels=["Negative", "Neutral", "Positive"]
)

# %%
### 2. Aspect-Based Sentiment Analysis (Simplified Example)
aspects = ["food", "service", "ambiance", "price", "cleanliness"]
aspect_sentiments = {aspect: [] for aspect in aspects}

for _, row in reviews.iterrows():
    review_text = row['review'].lower()
    for aspect in aspects:
        if aspect in review_text:
            aspect_sentiments[aspect].append(row['sentiment_score'])

# Calculate average sentiment for each aspect
aspect_avg_sentiment = {
    aspect: (sum(scores) / len(scores)) if scores else 0
    for aspect, scores in aspect_sentiments.items()
}

# %%
### 3. Topic Modeling
vectorizer = CountVectorizer(max_features=5000, stop_words='english')
X = vectorizer.fit_transform(reviews['review'])

lda = LatentDirichletAllocation(n_components=5, random_state=42)  # Adjust n_components as needed
lda.fit(X)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=42)

# %%
# Extract top words per topic
words = vectorizer.get_feature_names_out()
topics = {}
for topic_idx, topic in enumerate(lda.components_):
    top_features_ind = topic.argsort()[:-11:-1]  # Top 10 words
    top_features = [words[i] for i in top_features_ind]
    topics[topic_idx] = top_features

# %%
### 4. Keyword and Phrase Extraction by Sentiment

# Filter positive and negative reviews
positive_reviews = reviews[reviews['sentiment_category'] == "Positive"]
negative_reviews = reviews[reviews['sentiment_category'] == "Negative"]

# Generate word cloud for positive reviews
positive_wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white'
).generate(' '.join(positive_reviews['review']))

# Generate word cloud for negative reviews
negative_wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white'
).generate(' '.join(negative_reviews['review']))

# Plot word clouds side by side
plt.figure(figsize=(16, 8))

# Positive word cloud
plt.subplot(1, 2, 1)
plt.imshow(positive_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Positive Reviews Word Cloud', fontsize=16)

# Negative word cloud
plt.subplot(1, 2, 2)
plt.imshow(negative_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Negative Reviews Word Cloud', fontsize=16)

plt.tight_layout()
plt.show()

# %%
### 5. Sentiment Trends Over Time
# Convert 'date' column to datetime if not already in datetime format
reviews['date_of_review'] = pd.to_datetime(reviews['date_of_review'])

# Group by year-month and calculate average sentiment score
sentiment_trend = reviews.groupby(reviews['date_of_review'].dt.to_period("M"))['sentiment_score'].mean()

# Convert index to string for clearer x-axis labels
sentiment_trend.index = sentiment_trend.index.astype(str)

# Plot the sentiment trend
plt.figure(figsize=(12, 6))
plt.plot(sentiment_trend.index, sentiment_trend.values, marker='o', linestyle='-', linewidth=2)
plt.title("Sentiment Trend Over Time (Year-Month)", fontsize=16)
plt.xlabel("Year-Month", fontsize=12)
plt.ylabel("Average Sentiment Score", fontsize=12)
plt.xticks(rotation=45, fontsize=10)  # Rotate x-axis labels for better readability
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
### 6. Bigrams Analysis

def extract_top_bigrams(reviews, n=10):
    """Extract the top bigrams from a given list of reviews."""
    vectorizer = CountVectorizer(ngram_range=(2, 2), stop_words='english')
    bigrams_matrix = vectorizer.fit_transform(reviews)
    bigrams_sum = bigrams_matrix.sum(axis=0)  # Sum up the occurrences of each bigram
    
    # Get bigram names and their counts
    bigrams = vectorizer.get_feature_names_out()
    counts = bigrams_matrix.toarray().sum(axis=0)
    bigrams_df = pd.DataFrame({'bigram': bigrams, 'count': counts})
    bigrams_df = bigrams_df.sort_values(by='count', ascending=False).head(n)
    return bigrams_df

# Separate reviews based on sentiment
positive_reviews = reviews[reviews['sentiment_category'] == "Positive"]['review']
negative_reviews = reviews[reviews['sentiment_category'] == "Negative"]['review']
all_reviews = reviews['review']

# Extract top bigrams
top_positive_bigrams = extract_top_bigrams(positive_reviews, n=10)
top_negative_bigrams = extract_top_bigrams(negative_reviews, n=10)
top_overall_bigrams = extract_top_bigrams(all_reviews, n=10)

# Function to plot bigrams
def plot_bigrams(bigrams_df, title):
    plt.figure(figsize=(10, 6))
    plt.barh(bigrams_df['bigram'], bigrams_df['count'], color='skyblue', edgecolor='black')
    plt.title(title, fontsize=16)
    plt.xlabel('Count', fontsize=12)
    plt.ylabel('Bigrams', fontsize=12)
    plt.gca().invert_yaxis()  # Invert y-axis for better readability
    plt.grid(axis='x', alpha=0.3)
    plt.tight_layout()
    plt.show()

# Plot bigrams for positive, negative, and overall reviews
print("\nTop Positive Bigrams:")
plot_bigrams(top_positive_bigrams, "Top 10 Bigrams in Positive Reviews")

print("\nTop Negative Bigrams:")
plot_bigrams(top_negative_bigrams, "Top 10 Bigrams in Negative Reviews")

print("\nTop Overall Bigrams:")
plot_bigrams(top_overall_bigrams, "Top 10 Bigrams in Overall Reviews")
# Out:
# Top Positive Bigrams:
# Top Negative Bigrams:
# C:\Users\user\AppData\Local\Temp\ipykernel_19968\1768687728.py:35: UserWarning: Glyph 12615 (\N{HANGUL LETTER IEUNG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_19968\1768687728.py:35: UserWarning: Glyph 12609 (\N{HANGUL LETTER MIEUM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_19968\1768687728.py:35: UserWarning: Glyph 12623 (\N{HANGUL LETTER A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_19968\1768687728.py:35: UserWarning: Glyph 12601 (\N{HANGUL LETTER RIEUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12615 (\N{HANGUL LETTER IEUNG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12609 (\N{HANGUL LETTER MIEUM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12623 (\N{HANGUL LETTER A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12601 (\N{HANGUL LETTER RIEUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# Top Overall Bigrams:

# %%
from tabulate import tabulate

### 7. Complaint Detection

# Filter reviews with negative sentiment
complaints = reviews[reviews['sentiment_category'] == "Negative"]

### Results Summary

# 1. Aspect-Based Sentiment Analysis Averages

# Plot Aspect-Based Sentiment Analysis Averages in a Bar Chart
aspects = [aspect.capitalize() for aspect in aspect_avg_sentiment.keys()]
average_sentiments = list(aspect_avg_sentiment.values())

plt.figure(figsize=(10, 6))
plt.bar(aspects, average_sentiments, color='skyblue', edgecolor='black')
plt.title("Aspect-Based Sentiment Analysis Averages", fontsize=16)
plt.xlabel("Aspects", fontsize=12)
plt.ylabel("Average Sentiment Score", fontsize=12)
plt.ylim(-1, 1)  # Sentiment polarity ranges from -1 to 1
plt.axhline(0, color='gray', linewidth=0.8, linestyle='--')  # Reference line at 0
plt.grid(axis='y', alpha=0.3)

# Annotate each bar with the sentiment score
for i, score in enumerate(average_sentiments):
    plt.text(i, score + 0.02 if score >= 0 else score - 0.05, f"{score:.2f}", ha='center', fontsize=10)

plt.tight_layout()
plt.show()

# 2. Top Words in Topics
print("\nTop Words in Topics:")
for topic_num, topic_words in topics.items():
    print(f"\nTopic {topic_num + 1}:")
    print(", ".join(topic_words))

# 3. Display a Word Cloud for Topics
topic_wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white'
).generate(" ".join([" ".join(words) for words in topics.values()]))

plt.figure(figsize=(10, 6))
plt.imshow(topic_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Top Words in Topics', fontsize=16)
plt.show()

# 4. Sample Negative Reviews
print("\nSample Negative Reviews (Complaints):")
if not complaints.empty:
    # Display top 5 complaints
    styled_complaints = complaints[['review']].head(5).style.set_properties(**{
        'border': '1px solid black', 
        'padding': '10px'
    }).set_table_styles([
        {'selector': 'th', 'props': [('background-color', '#f4f4f4'), ('font-weight', 'bold')]}
    ])
    display(styled_complaints)
else:
    print("No negative reviews found.")
# Out:
# Top Words in Topics:
#
# Topic 1:
# menu, amazing, excellent, dishes, restaurant, served, place, ordered, way, wine
#
# Topic 2:
# service, food, restaurant, experience, michelin, wine, good, dinner, star, great
#
# Topic 3:
# experience, service, restaurant, menu, dishes, chef, wonderful, excellent, tasting, food
#
# Topic 4:
# menu, food, service, wine, experience, restaurant, tasting, good, great, best
#
# Topic 5:
# experience, best, food, restaurant, service, cuisine, excellent, dishes, menu, staff
# Sample Negative Reviews (Complaints):
# <style type="text/css">
# #T_e6af8 th {
#   background-color: #f4f4f4;
#   font-weight: bold;
# }
# #T_e6af8_row0_col0, #T_e6af8_row1_col0, #T_e6af8_row2_col0, #T_e6af8_row3_col0, #T_e6af8_row4_col0 {
#   border: 1px solid black;
#   padding: 10px;
# }
# </style>
# <table id="T_e6af8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6af8_level0_col0" class="col_heading level0 col0" >review</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6af8_level0_row0" class="row_heading level0 row0" >38</th>
#       <td id="T_e6af8_row0_col0" class="data row0 col0" >We came to Belcanto jetlagged but keen to have a culinary experience and that was exactly what we got. We had both the classic and landscapes menu and we both thought the landscape menu had a slight edge. Unfortunately we were unable to …</td>
#     </tr>
#     <tr>
#       <th id="T_e6af8_level0_row1" class="row_heading level0 row1" >75</th>
#       <td id="T_e6af8_row1_col0" class="data row1 col0" >We spent over 800 Euros for two people. The menu was very confusing. The food was TERRIBLE. It smelled old oil and had no flavors. We couldn't eat any but they didn't care. Though we asked medium, they served rare, almost blue. We heard …</td>
#     </tr>
#     <tr>
#       <th id="T_e6af8_level0_row2" class="row_heading level0 row2" >96</th>
#       <td id="T_e6af8_row2_col0" class="data row2 col0" >The amuse-bouche offered a glimpse of excitement, we went with the a la carte menu, the lobster appetiser was nice, but it turned to disappointment when the steak was destroyed with some awful sauce (see photos) …</td>
#     </tr>
#     <tr>
#       <th id="T_e6af8_level0_row3" class="row_heading level0 row3" >118</th>
#       <td id="T_e6af8_row3_col0" class="data row3 col0" >I've enjoyed many Michelin experiences over the years and this was the only time I've been so completely disappointed. Of the 10 courses, food started and finished well, but the other 7 in between were completely forgettable. Several of the …</td>
#     </tr>
#     <tr>
#       <th id="T_e6af8_level0_row4" class="row_heading level0 row4" >143</th>
#       <td id="T_e6af8_row4_col0" class="data row4 col0" >Simply not an experience that lives up to what you expect from Michelin guide entries. Having a hard time finding positives from this visit.</td>
#     </tr>
#   </tbody>
# </table>

# %%
### 8. Verdict

def should_recommend_restaurant_lenient(
    reviews, aspect_avg_sentiment, 
    sentiment_threshold=0.1, complaint_rate_threshold=0.2, score_threshold=3, critical_aspect_majority=True
):
    """
    Decide whether to recommend a restaurant based on lenient sentiment analysis and complaints.

    Parameters:
    - reviews (DataFrame): DataFrame with sentiment scores and sentiment categories.
    - aspect_avg_sentiment (dict): Dictionary of average sentiment scores for each aspect.
    - sentiment_threshold (float): Minimum average sentiment score for recommendation.
    - complaint_rate_threshold (float): Maximum acceptable proportion of negative reviews.
    - score_threshold (float): Minimum average score for recommendation.
    - critical_aspect_majority (bool): Whether to allow recommendation if majority of critical aspects are positive.

    Returns:
    - recommendation (str): Recommendation decision ("Recommend" or "Do Not Recommend").
    - details (dict): Breakdown of metrics used in the decision.
    """
    # Overall average sentiment score
    overall_sentiment = reviews['sentiment_score'].mean()
    
    # Complaint rate (proportion of negative reviews)
    complaint_rate = len(reviews[reviews['sentiment_category'] == "Negative"]) / len(reviews)
    
    # Average score from the 'score' column
    average_score = reviews['score'].mean()
    
    # Check critical aspects for positive sentiment
    critical_aspects = ['food', 'service', 'ambiance']
    critical_aspect_sentiments = {aspect: sentiment for aspect, sentiment in aspect_avg_sentiment.items() if aspect in critical_aspects}
    
    if critical_aspect_majority:
        # Check if the majority of critical aspects exceed the threshold
        critical_positive_count = sum(sentiment > sentiment_threshold for sentiment in critical_aspect_sentiments.values())
        critical_aspect_pass = critical_positive_count >= (len(critical_aspects) // 2 + 1)
    else:
        # Strict check: all critical aspects must exceed the threshold
        critical_aspect_pass = all(sentiment > sentiment_threshold for sentiment in critical_aspect_sentiments.values())
    
    # Make recommendation based on thresholds
    if overall_sentiment > sentiment_threshold and complaint_rate < complaint_rate_threshold and average_score >= score_threshold and critical_aspect_pass:
        recommendation = "Recommend"
    else:
        recommendation = "Do Not Recommend"
    
    # Compile decision details
    details = {
        "Overall Sentiment": f"{overall_sentiment:.2f}",
        "Complaint Rate": f"{complaint_rate:.2%}",
        "Average Score": f"{average_score:.2f}",
        "Critical Aspects Positive (Majority)" if critical_aspect_majority else "Critical Aspects Positive (Strict)": critical_aspect_pass,
        "Critical Aspect Sentiments": critical_aspect_sentiments,
        "Sentiment Threshold": sentiment_threshold,
        "Complaint Rate Threshold": complaint_rate_threshold,
        "Score Threshold": score_threshold
    }
    
    return recommendation, details

# Run the lenient recommendation decision
recommendation, decision_details = should_recommend_restaurant_lenient(reviews, aspect_avg_sentiment)

# Print the recommendation and details
print("\nRecommendation:", recommendation)
print("\nDecision Details:")
for key, value in decision_details.items():
    print(f"{key}: {value}")
# Out:
# Recommendation: Recommend
#
# Decision Details:
# Overall Sentiment: 0.42
# Complaint Rate: 6.21%
# Average Score: 4.50
# Critical Aspects Positive (Majority): True
# Critical Aspect Sentiments: {'food': 0.4576641193915003, 'service': 0.5177193026329932, 'ambiance': 0.5056117724867725}
# Sentiment Threshold: 0.1
# Complaint Rate Threshold: 0.2
# Score Threshold: 3
